# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
import matplotlib.pyplot as plt

# %%
# Load the OCR letter recognition dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data'
dataset = pd.read_csv(url, header=None)

# %%
# Split the dataset into features and labels
X = dataset.iloc[:, 1:].values  #selecting all rows and selecting all columns from index 1
y = dataset.iloc[:, 0].values   #selecting all rows and selecting column with index 0

# %%
print(y[0])
# Out:
# T

# %%
# Encode the labels into numeric value
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
print(y[0])
# Out:
# 19

# %%
#splitting dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train = X_train / 15.0
X_test = X_test / 15.0

# %%
#we are using sequential model where layers are stacked one after another,
#output of previous layer is given to as input to next layer

model = Sequential()
#1st layer is dense layer which consists on 128 neurons, since it is 1st layer we need to define input_shape of our training data
model.add(Dense(128, activation='relu', input_shape=(16,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(26, activation='softmax'))  #softmax is used to predict multiclass category outcome
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#now we will compile the model

#sparse_categorical_crossentropy (scce) produces a category index of the most likely matching category.
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
#The batch size is a number of samples processed before the model is updated.
#verbose is the choice that how you want to see the output of your Nural Network while it's training.
#If you set verbose = 0, It will show nothing
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=12, verbose=1)
# Out:
# Epoch 1/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1150 - loss: 3.0218 - val_accuracy: 0.5238 - val_loss: 1.8111
# Epoch 2/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.3753 - loss: 1.9698 - val_accuracy: 0.6077 - val_loss: 1.4233
# Epoch 3/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4754 - loss: 1.6790 - val_accuracy: 0.6465 - val_loss: 1.2254
# Epoch 4/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5285 - loss: 1.4995 - val_accuracy: 0.6780 - val_loss: 1.1453
# Epoch 5/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5564 - loss: 1.4178 - val_accuracy: 0.6950 - val_loss: 1.0464
# Epoch 6/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5725 - loss: 1.3644 - val_accuracy: 0.7180 - val_loss: 0.9959
# Epoch 7/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.5898 - loss: 1.2943 - val_accuracy: 0.7410 - val_loss: 0.9420
# Epoch 8/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6077 - loss: 1.2453 - val_accuracy: 0.7358 - val_loss: 0.9245
# Epoch 9/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.6120 - loss: 1.2271 - val_accuracy: 0.7520 - val_loss: 0.8731
# Epoch 10/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6253 - loss: 1.1897 - val_accuracy: 0.7542 - val_loss: 0.8582
# Epoch 11/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - accuracy: 0.6232 - loss: 1.1908 - val_accuracy: 0.7563 - val_loss: 0.8313
# Epoch 12/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6331 - loss: 1.1526 - val_accuracy: 0.7688 - val_loss: 0.7969
# Epoch 13/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6473 - loss: 1.1349 - val_accuracy: 0.7628 - val_loss: 0.7934
# Epoch 14/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6467 - loss: 1.1048 - val_accuracy: 0.7755 - val_loss: 0.7702
# Epoch 15/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6463 - loss: 1.1182 - val_accuracy: 0.7675 - val_loss: 0.7561
# Epoch 16/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.6613 - loss: 1.0699 - val_accuracy: 0.7785 - val_loss: 0.7644
# Epoch 17/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6653 - loss: 1.0571 - val_accuracy: 0.7757 - val_loss: 0.7461
# Epoch 18/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.6652 - loss: 1.0378 - val_accuracy: 0.7918 - val_loss: 0.7053
# Epoch 19/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.6704 - loss: 1.0259 - val_accuracy: 0.7947 - val_loss: 0.7018
# Epoch 20/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6720 - loss: 1.0338 - val_accuracy: 0.7945 - val_loss: 0.6907
# Epoch 21/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.6804 - loss: 1.0145 - val_accuracy: 0.7952 - val_loss: 0.6905
# Epoch 22/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6742 - loss: 1.0153 - val_accuracy: 0.7950 - val_loss: 0.6813
# Epoch 23/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6820 - loss: 1.0008 - val_accuracy: 0.7975 - val_loss: 0.6908
# Epoch 24/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6830 - loss: 0.9825 - val_accuracy: 0.8045 - val_loss: 0.6451
# Epoch 25/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6830 - loss: 0.9940 - val_accuracy: 0.8025 - val_loss: 0.6559
# Epoch 26/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6929 - loss: 0.9574 - val_accuracy: 0.7980 - val_loss: 0.6660
# Epoch 27/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6981 - loss: 0.9512 - val_accuracy: 0.8048 - val_loss: 0.6409
# Epoch 28/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6914 - loss: 0.9744 - val_accuracy: 0.8023 - val_loss: 0.6269
# Epoch 29/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6811 - loss: 0.9850 - val_accuracy: 0.7968 - val_loss: 0.6373
# Epoch 30/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6923 - loss: 0.9619 - val_accuracy: 0.8115 - val_loss: 0.6316
# Epoch 31/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.6949 - loss: 0.9765 - val_accuracy: 0.8123 - val_loss: 0.6302
# Epoch 32/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.6968 - loss: 0.9627 - val_accuracy: 0.8177 - val_loss: 0.5949
# Epoch 33/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.7013 - loss: 0.9466 - val_accuracy: 0.8142 - val_loss: 0.6149
# Epoch 34/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - accuracy: 0.6996 - loss: 0.9584 - val_accuracy: 0.8160 - val_loss: 0.6087
# Epoch 35/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7077 - loss: 0.9219 - val_accuracy: 0.8117 - val_loss: 0.6050
# Epoch 36/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7066 - loss: 0.9244 - val_accuracy: 0.8138 - val_loss: 0.5950
# Epoch 37/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6991 - loss: 0.9414 - val_accuracy: 0.8125 - val_loss: 0.6112
# Epoch 38/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7044 - loss: 0.9359 - val_accuracy: 0.8235 - val_loss: 0.5959
# Epoch 39/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7057 - loss: 0.9304 - val_accuracy: 0.8223 - val_loss: 0.5901
# Epoch 40/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6990 - loss: 0.9418 - val_accuracy: 0.8142 - val_loss: 0.5843
# Epoch 41/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7014 - loss: 0.9294 - val_accuracy: 0.8223 - val_loss: 0.5740
# Epoch 42/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7175 - loss: 0.8956 - val_accuracy: 0.8165 - val_loss: 0.5838
# Epoch 43/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7163 - loss: 0.8919 - val_accuracy: 0.8217 - val_loss: 0.5717
# Epoch 44/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7166 - loss: 0.9048 - val_accuracy: 0.8282 - val_loss: 0.5691
# Epoch 45/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7219 - loss: 0.8989 - val_accuracy: 0.8310 - val_loss: 0.5788
# Epoch 46/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7132 - loss: 0.9037 - val_accuracy: 0.8260 - val_loss: 0.5696
# Epoch 47/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7098 - loss: 0.9113 - val_accuracy: 0.8267 - val_loss: 0.5811
# Epoch 48/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7100 - loss: 0.9093 - val_accuracy: 0.8345 - val_loss: 0.5401
# Epoch 49/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7114 - loss: 0.9066 - val_accuracy: 0.8360 - val_loss: 0.5622
# Epoch 50/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7191 - loss: 0.8942 - val_accuracy: 0.8317 - val_loss: 0.5519

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", accuracy)
print("Test loss:", loss)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8329 - loss: 0.5585
# Test accuracy: 0.8317499756813049
# Test loss: 0.5519418716430664

# %%
model.save('ocr_model.h5')
# Save the trained model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
model = load_model('ocr_model.h5')
# Load the trained model
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
sample_records = X_test[:1000]
# Select a few records for classification

# %%
# Perform classification
predictions = model.predict(sample_records)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
predicted_labels = np.argmax(predictions, axis=1)



predicted_letters = label_encoder.inverse_transform(predicted_labels)

# Also decode the actual labels (use y_test[:1000] instead of y)
# actual_letters = label_encoder.inverse_transform(y_test[:1000])
actual_letters = label_encoder.inverse_transform(y_test)

# %%
# Calculate accuracy
accuracy = np.sum(predicted_labels == y[:1000]) / len(predicted_labels)

# %%
# Print the predicted labels and corresponding actual labels
print("Predicted Labels\tActual Labels")
for i in range(len(predicted_letters)):
    print(f"{predicted_letters[i]}\t\t\t{actual_letters[i]}")
# Out:
# Predicted Labels	Actual Labels
# D			D
# D			D
# V			V
# B			B
# H			H
# N			N
# R			E
# Q			Q
# X			R
# N			N
# Q			Q
# O			O
# N			N
# D			D
# I			I
# M			M
# U			U
# S			S
# O			O
# A			A
# X			X
# A			A
# K			K
# S			S
# O			O
# V			V
# Y			Y
# J			J
# D			D
# V			V
# N			D
# V			V
# K			K
# Y			F
# N			N
# I			I
# G			G
# T			T
# H			H
# K			K
# J			J
# O			O
# M			M
# T			T
# B			B
# Q			Q
# Z			Z
# C			C
# D			D
# X			X
# K			C
# G			G
# Q			Q
# F			F
# N			N
# Y			Y
# Z			Z
# K			K
# C			C
# E			T
# M			M
# W			V
# Q			G
# R			M
# D			D
# T			T
# H			H
# P			P
# N			N
# C			C
# O			O
# X			X
# X			X
# Q			Q
# V			V
# F			P
# V			V
# G			G
# W			W
# O			H
# P			P
# O			O
# I			I
# G			G
# X			X
# Y			X
# Y			P
# W			W
# O			Q
# D			D
# D			N
# Q			Q
# T			T
# T			T
# Y			V
# Y			Y
# I			T
# V			V
# J			J
# M			U
# D			D
# L			L
# M			M
# Y			Y
# E			E
# M			M
# A			A
# Y			Y
# K			K
# Y			Y
# U			U
# U			U
# U			U
# K			C
# Q			Q
# I			I
# A			A
# E			E
# D			D
# T			T
# S			P
# Q			Q
# Z			Z
# G			G
# X			X
# G			G
# F			F
# M			M
# S			S
# E			E
# E			E
# K			K
# Z			Z
# K			X
# O			O
# E			E
# U			U
# I			I
# R			R
# O			O
# M			M
# J			J
# F			F
# K			K
# M			M
# N			N
# G			T
# D			D
# H			H
# R			R
# L			L
# Z			Z
# F			F
# V			V
# W			W
# E			E
# T			T
# W			W
# Y			Y
# Q			Q
# L			L
# F			F
# O			O
# D			D
# K			K
# S			I
# T			X
# P			P
# H			H
# Q			Z
# D			H
# W			W
# T			F
# B			B
# R			R
# O			O
# B			B
# S			Z
# N			N
# W			W
# Z			Z
# W			W
# V			V
# B			S
# V			Y
# H			H
# O			O
# T			Y
# V			V
# B			S
# W			W
# B			B
# P			P
# D			D
# Z			Z
# O			O
# X			X
# F			P
# B			B
# P			S
# T			T
# X			X
# J			J
# B			B
# Y			Y
# S			I
# Z			Z
# Z			Z
# P			P
# E			E
# K			H
# Q			Q
# F			I
# A			A
# H			H
# P			P
# E			E
# U			U
# K			K
# P			P
# N			M
# C			C
# X			Y
# J			J
# W			W
# M			M
# G			G
# J			J
# O			O
# T			H
# P			P
# L			L
# W			W
# A			A
# C			C
# C			C
# C			C
# O			O
# J			J
# Y			Y
# P			P
# Y			Y
# A			A
# R			R
# Z			Z
# J			J
# I			I
# G			G
# G			G
# I			I
# K			K
# G			M
# R			R
# T			T
# D			D
# E			E
# D			D
# L			L
# W			W
# G			P
# L			L
# U			U
# O			O
# T			T
# A			A
# V			V
# D			D
# U			U
# X			X
# X			X
# G			G
# C			C
# D			F
# Z			Z
# W			W
# T			T
# V			V
# T			T
# P			P
# M			M
# S			S
# U			U
# H			F
# Q			Q
# B			B
# G			G
# K			K
# L			L
# F			F
# E			E
# R			R
# P			P
# R			R
# W			W
# I			I
# Y			Y
# Y			Y
# B			B
# C			C
# T			T
# M			M
# M			M
# O			N
# B			B
# R			R
# Z			Z
# G			G
# D			D
# R			R
# I			I
# Y			Y
# F			P
# M			M
# A			A
# B			B
# M			M
# R			F
# O			G
# Q			Q
# Z			Z
# P			P
# O			O
# Q			Q
# P			P
# B			G
# N			N
# O			O
# T			T
# G			G
# S			S
# V			V
# A			Z
# A			A
# D			P
# J			J
# O			O
# N			N
# S			Q
# K			K
# X			X
# S			E
# F			P
# J			J
# N			N
# X			X
# X			X
# V			V
# Q			Q
# Y			H
# A			A
# T			T
# S			S
# W			W
# M			M
# P			P
# Y			Y
# B			U
# S			Z
# R			R
# B			B
# A			A
# Y			Y
# F			F
# F			F
# D			D
# A			A
# N			N
# A			A
# N			H
# Q			Q
# P			P
# Z			Z
# R			R
# D			D
# W			W
# O			O
# Q			Q
# K			K
# N			N
# W			W
# P			P
# W			W
# S			S
# K			K
# S			S
# I			J
# E			E
# S			S
# V			V
# S			S
# O			O
# V			V
# G			T
# X			X
# Q			Q
# W			W
# I			I
# Z			Z
# D			D
# F			F
# P			P
# R			R
# P			P
# C			C
# D			D
# J			J
# G			L
# I			I
# D			H
# X			X
# B			D
# U			U
# G			G
# O			O
# K			K
# K			K
# K			K
# P			P
# P			P
# G			G
# T			T
# F			F
# B			B
# Y			Y
# V			Y
# I			I
# H			H
# E			E
# S			S
# Y			Y
# S			S
# T			T
# Q			Q
# L			L
# R			M
# I			I
# Z			Z
# F			F
# A			A
# J			J
# B			V
# G			G
# U			U
# Z			Z
# H			H
# O			O
# D			N
# S			J
# U			T
# O			O
# H			H
# Q			V
# F			F
# L			L
# W			W
# M			M
# T			Y
# J			J
# P			P
# W			W
# E			E
# A			A
# B			B
# W			N
# O			O
# Y			Q
# Y			Y
# Q			Q
# F			F
# A			A
# A			A
# Q			Q
# Z			Z
# E			E
# R			H
# N			N
# E			E
# A			A
# R			R
# G			C
# Z			Z
# Q			Q
# V			V
# O			O
# F			T
# K			K
# M			M
# R			R
# Y			Y
# X			X
# X			X
# J			J
# X			X
# Q			Q
# T			T
# S			S
# A			A
# X			X
# G			G
# T			T
# N			N
# B			S
# Y			Y
# P			P
# A			A
# S			I
# T			T
# O			X
# X			X
# C			C
# O			O
# B			B
# G			G
# R			W
# D			D
# K			K
# U			U
# S			S
# W			O
# Z			Z
# S			L
# N			N
# R			R
# V			V
# A			A
# K			L
# B			D
# W			W
# I			I
# B			O
# K			C
# W			W
# A			A
# Y			Y
# Q			Q
# L			L
# Q			Q
# K			K
# J			J
# E			E
# B			B
# P			P
# J			J
# R			R
# X			X
# N			N
# A			A
# G			G
# C			C
# H			T
# L			L
# S			S
# A			A
# N			N
# R			K
# V			V
# B			G
# A			A
# D			D
# H			H
# Y			Y
# Z			Z
# Q			Q
# C			C
# U			U
# Q			Q
# Z			Z
# M			M
# D			D
# B			B
# L			L
# B			R
# Q			Q
# D			D
# F			F
# W			W
# Q			Q
# M			M
# G			G
# S			Z
# B			B
# U			U
# N			N
# K			K
# Q			P
# A			A
# U			U
# P			F
# T			T
# X			X
# L			L
# U			U
# Y			Y
# P			P
# Y			Y
# B			R
# S			S
# K			K
# Q			E
# Q			Q
# F			F
# W			W
# Q			P
# P			P
# M			M
# N			N
# Z			Z
# G			G
# R			K
# O			O
# W			W
# I			I
# I			C
# E			E
# U			U
# R			R
# F			I
# Y			Y
# O			S
# V			V
# R			R
# C			C
# Q			Q
# C			C
# Z			J
# Y			Y
# S			S
# K			K
# G			L
# X			X
# T			T
# I			I
# D			F
# W			W
# A			A
# O			D
# K			K
# A			A
# Z			Z
# M			M
# G			G
# G			G
# W			W
# W			W
# Z			Z
# W			W
# T			T
# O			O
# H			R
# T			T
# N			N
# L			S
# Q			Q
# J			J
# Q			Q
# M			M
# O			O
# A			A
# N			N
# Z			Z
# D			D
# T			T
# I			I
# U			U
# A			A
# O			N
# O			G
# O			P
# L			L
# T			F
# R			R
# C			C
# P			P
# Y			Y
# Y			Y
# T			T
# A			A
# S			Y
# T			T
# Q			E
# T			T
# O			O
# S			S
# N			N
# O			O
# I			I
# O			O
# U			U
# N			N
# Z			Z
# J			J
# C			C
# N			H
# S			S
# G			L
# H			H
# E			C
# Q			Q
# F			F
# B			B
# W			O
# I			I
# K			K
# O			O
# O			R
# E			E
# L			L
# M			M
# L			L
# X			T
# E			E
# U			U
# W			W
# G			F
# D			D
# N			N
# V			V
# M			M
# I			I
# X			K
# L			L
# Y			Y
# Q			Q
# F			F
# U			U
# J			J
# V			V
# M			M
# P			P
# W			W
# L			L
# A			A
# L			L
# B			B
# Y			Y
# I			I
# D			D
# R			R
# T			T
# Q			Q
# B			B
# O			U
# M			M
# O			O
# I			I
# U			U
# U			U
# X			K
# S			J
# I			I
# W			W
# Z			Z
# Z			Z
# P			P
# A			A
# Z			Z
# P			P
# V			V
# O			G
# B			B
# G			G
# O			O
# V			V
# D			D
# Z			Z
# Y			Y
# P			P
# Q			Q
# A			A
# E			E
# W			W
# D			D
# J			J
# I			I
# J			J
# X			X
# B			S
# Z			Z
# G			G
# X			T
# U			U
# K			K
# G			G
# I			I
# N			N
# S			I
# W			W
# I			I
# I			I
# P			P
# B			B
# O			O
# H			H
# F			D
# O			O
# N			N
# Z			S
# D			D
# B			S
# M			M
# O			O
# W			N
# Y			Y
# Y			X
# Q			Q
# N			M
# R			R
# G			G
# Q			G
# A			A
# B			K
# U			U
# U			O
# B			P
# C			C
# V			V
# D			D
# B			B
# A			A
# G			E
# D			R
# T			T
# I			I
# S			Z
# N			N
# O			O
# B			B
# C			C
# G			G
# J			J
# E			E
# N			N
# J			J
# Q			H
# D			P
# O			O
# O			O
# B			B
# X			X
# B			D
# S			S
# O			O
# O			O
# G			G
# B			B
# R			H
# C			C
# A			A
# W			W
# P			P
# I			I
# N			N
# M			M
# G			G
# N			N
# A			A
# Y			H
# U			K
# N			N
# M			M
# F			F
# W			W
# A			A
# S			S
# E			E
# U			T
# J			J
# H			H
# N			N
# K			K
# W			W
# W			W
# U			U
# S			L
# Z			Z
# Z			Z
# Z			Z
# G			G
# T			T
# J			J
# V			V
# W			W
# L			L
# M			M
# U			U
# W			W
# Q			G
# A			A
# T			T
# J			J
# C			C
# G			G
# D			D
# T			Y
# Y			Y
# X			X
# N			N
# Y			Y
# Z			S
# K			K
# U			U
# W			W
# R			R
# B			B
# T			T
# R			R
# H			H
# R			R
# M			M
# O			O
# W			W
# X			X
# R			R
# X			X
# N			N
# N			H
# C			C
# E			C
# J			J
# V			V
# V			V
# I			I
# R			R
# W			W
# O			H
# N			N
# E			E
# U			U
# M			M
# A			A
# B			B
# E			E
# K			K
# T			T
# F			F
# Y			Y
# D			T
# H			H
# W			W
# W			W
# O			O
# Q			G
# W			W
# L			L
# Q			Q
# R			R
# U			K
# D			D
# P			P
# T			T
# B			B
# B			L
# V			V
# Q			Q
# G			G
# B			S
# G			W
# V			V
# L			L
# D			D
# R			R
# L			L
# C			C
# N			N
# V			V
# I			I
# P			P
# K			C
# F			F
# W			W
# A			A
# P			P
# F			T
# H			H
# B			B
# K			K
# I			I
# W			W
# D			R
# J			J
# E			R
# K			K
# A			A
# Q			Q
# Q			Q
# A			A
# M			M
# V			V
# U			U
# G			G
# O			O
# U			U
# D			H
# V			V
# G			G
# Q			Q
# I			I
# T			T
# G			G
# F			I
